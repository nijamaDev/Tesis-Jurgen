# %%
import matplotlib.pyplot as plt
import numpy as np

procesador = ['i9', 'i9', 'Xeon', 'Xeon']
hilos_ejecucion = [10, 20, 4, 8]
tiempo = [1251.51, 1314.96, 3864.86, 3907.69]

# Crear subgrupos de procesadores
grupos = ['i9', 'Xeon']
i9_indices = [0, 1]
xeon_indices = [2, 3]

# Ancho de las barras
bar_width = 0.4

# Crear figura y ejes
fig, ax = plt.subplots(figsize=(4, 4))

# Crear barras para i9 y Xeon
bar1 = plt.bar(i9_indices, [tiempo[i] for i in i9_indices], bar_width, color='b', label='i9')
bar2 = plt.bar(xeon_indices, [tiempo[i] for i in xeon_indices], bar_width, color='g', label='Xeon')

# Configurar ejes y etiquetas
plt.xlabel('Hilos de Ejecución')
plt.ylabel('Tiempo (s)')
plt.title('Hilos de Ejecución vs Tiempo')
plt.xticks(np.arange(len(hilos_ejecucion)), hilos_ejecucion)
plt.legend()
plt.ylim(0, 4300)

# Anotar los valores encima de las barras
for rect in bar1 + bar2:
    height = rect.get_height()
    plt.text(rect.get_x() + rect.get_width() / 2, height, f'{height:.2f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the chart
data = [
    (500, 'i9', 1, 10, 1251.51),
    (1000, 'i9', 1, 10, 2502.77),
    (2500, 'i9', 1, 10, 6345.83),
    (5000, 'i9', 1, 10, 12729.11),
    (500, 'Xeon', 1, 4, 3864.86),
    (1000, 'Xeon', 1, 4, 7749.36),
    (2500, 'Xeon', 1, 4, 19342.18),
    (5000, 'Xeon', 1, 4, 38678.7),
    (500, 'Xeon', 10, 4, 405.68),
    (1000, 'Xeon', 10, 4, 793.469),
    (2500, 'Xeon', 10, 4, 1963.345),
    (5000, 'Xeon', 10, 4, 3911.62),
    (500, 'Xeon', 20, 4, 207.055),
    (1000, 'Xeon', 20, 4, 401.64),
    (2500, 'Xeon', 20, 4, 979.18),
    (5000, 'Xeon', 20, 4, 1943.21),
    (500, 'Xeon', 30, 4, 141.618),
    (1000, 'Xeon', 30, 4, 275.055),
    (2500, 'Xeon', 30, 4, 659.21),
    (5000, 'Xeon', 30, 4, 1303.25)
]

# Grouping data by processor type
processors = {}
for entry in data:
    _, processor, nodes, task_per_node, time = entry
    label = f"{processor}, Nodes: {nodes}, Threads: {task_per_node}"
    if label in processors:
        processors[label].append((entry[0], time))
    else:
        processors[label] = [(entry[0], time)]


# Creating the chart
x_ticks = sorted(set(entry[0] for entry in data + new_data))
x_labels = [f"{x}" for x in x_ticks]
fig, ax = plt.subplots(figsize=(5, 6))
for processor, values in processors.items():
    x_data, y_data = zip(*values)
    plt.plot(x_data, y_data, label=processor, marker='o', linestyle='-')
    plt.scatter(x_data[:-2], y_data[:-2], color='blue', marker='o')
    for i, txt in enumerate(y_data[-1:]):
        if processor == 'Xeon, Nodes: 30, Threads: 4':
            plt.annotate(f"{txt:.2f}", (x_data[i-1], y_data[i-1]), xytext=(x_data[i-1], y_data[i-1]-1800), ha='center', va='bottom')
        else:
            plt.annotate(f"{txt:.2f}", (x_data[i-1], y_data[i-1]), xytext=(x_data[i-1], y_data[i-1]+300), ha='center', va='bottom')
    
# Setting y-axis limits
plt.xlim(0, 5500)
#plt.ylim(0, 13500)

# Adding labels and title
plt.xlabel('n')
plt.ylabel('Time')
plt.title('Execution Time by Configuration')
plt.xticks(x_ticks, x_labels)
plt.legend()

# Displaying the chart
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

nodes = [1, 10, 20, 30]
cores_per_node = [4, 4, 4, 4]
speedup = [1, 9.888153762, 19.904539406, 29.678649548]

plt.figure(figsize=(6, 4))  # Increase the height by adjusting the figsize

plt.bar(nodes, speedup, width=3, color='#FF6961')
plt.xlabel('Nodos')
plt.ylabel('Factor de Optimización de Tiempo')
plt.title('Factor de Optimización de Tiempo vs. Cantidad de Nodos (Xeon)')

plt.xticks(nodes)  # Set the x-axis labels to the values of 'nodes'

for i, bar in enumerate(bars):
    if i == 0:
        plt.annotate(f'{speedup[i]:.2f}', (bar.get_x() + bar.get_width() / 2, bar.get_height()), 
                     textcoords="offset points", xytext=(0, 5), ha='center')
    else:
        plt.annotate(f'{speedup[i]:.2f}', (bar.get_x() + bar.get_width() / 2, bar.get_height()), 
                     textcoords="offset points", xytext=(-33, -10), ha='center')


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for the chart
data = [
    (500, 'i9', 1, 10, 1251.51),
    (1000, 'i9', 1, 10, 2502.77),
    (2500, 'i9', 1, 10, 6345.83),
    (5000, 'i9', 1, 10, 12729.11),
    (500, 'Xeon', 1, 4, 3864.86),
    (1000, 'Xeon', 1, 4, 7749.36),
    (2500, 'Xeon', 1, 4, 19342.18),
    (5000, 'Xeon', 1, 4, 38678.7),
    (500, 'Xeon', 10, 4, 405.68),
    (1000, 'Xeon', 10, 4, 793.469),
    (2500, 'Xeon', 10, 4, 1963.345),
    (5000, 'Xeon', 10, 4, 3911.62),
    (500, 'Xeon', 20, 4, 207.055),
    (1000, 'Xeon', 20, 4, 401.64),
    (2500, 'Xeon', 20, 4, 979.18),
    (5000, 'Xeon', 20, 4, 1943.21),
    (500, 'Xeon', 30, 4, 141.618),
    (1000, 'Xeon', 30, 4, 275.055),
    (2500, 'Xeon', 30, 4, 659.21),
    (5000, 'Xeon', 30, 4, 1303.25)
]

# Grouping data by processor type
processors = {}
for entry in data:
    _, processor, nodes, task_per_node, time = entry
    label = f"{processor}, Nodes: {nodes}, Threads: {task_per_node}"
    if label in processors:
        processors[label].append((entry[0], time))
    else:
        processors[label] = [(entry[0], time)]


# Creating the chart
x_ticks = sorted(set(entry[0] for entry in data + new_data))
x_labels = [f"{x}" for x in x_ticks]
fig, ax = plt.subplots(figsize=(5, 6))
for processor, values in processors.items():
    x_data, y_data = zip(*values)
    plt.plot(x_data, y_data, label=processor, marker='o', linestyle='-')
    plt.scatter(x_data[:-2], y_data[:-2], color='blue', marker='o')
    for i, txt in enumerate(y_data[-1:]):
        if processor == 'Xeon, Nodes: 30, Threads: 4':
            plt.annotate(f"{txt:.2f}", (x_data[i-1], y_data[i-1]), xytext=(x_data[i-1], y_data[i-1]-1800), ha='center', va='bottom')
        else:
            plt.annotate(f"{txt:.2f}", (x_data[i-1], y_data[i-1]), xytext=(x_data[i-1], y_data[i-1]+300), ha='center', va='bottom')
    
# Setting y-axis limits
plt.xlim(0, 5500)
#plt.ylim(0, 13500)

# Adding labels and title
plt.xlabel('n')
plt.ylabel('Time')
plt.title('Execution Time by Configuration')
plt.xticks(x_ticks, x_labels)
plt.legend()

# Displaying the chart
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

nodos = list(range(1, 21))
tareas_por_nodo = 4
tiempo = [1949.51, 872.24, 588.31, 454.89, 375.38, 315.59, 272.35, 247.69, 233.20, 211.49, 205.22, 179.98, 173.37, 165.38, 154.25, 284.55, 147.61, 266.26, 266.62, 241.35]
gflops = [13.651, 30.512, 45.237, 58.505, 70.897, 84.329, 97.719, 107.45, 114.12, 125.84, 129.68, 147.87, 153.51, 160.92, 172.53, 93.528, 180.30, 99.953, 99.817, 110.27]

nodos_extra = list(range(1, 21))
tiempo_extra = [633.87, 334.06, 255.94, 205.84, 184.57, 177.01, 159.65, 144.49, 146.02, 138.39, 134.47, 122.86, 128.06, 129.06, 291.20, 109.06, 271.88, 259.25, 462.81, 243.71]
gflops_extra = [41.986, 79.668, 103.98, 129.29, 144.19, 150.35, 166.70, 184.19, 182.26, 192.31, 197.91, 216.61, 207.82, 206.20, 91.393, 244.03, 97.888, 102.65, 57.504, 109.20]

fig, ax1 = plt.subplots()

color1 = 'tab:red'
color1_dark = '#ff7878'
color2 = '#0066ff'
color2_dark = "#8cbaff"
ax1.set_xlabel('Nodos')
ax1.set_ylabel('Tiempo', color=color1)
ax1.plot(nodos, tiempo, color=color1, marker='o', label='Datos originales')
ax1.plot(nodos_extra, tiempo_extra, color=color2, marker='o', linestyle='-', label='Nuevos datos')
ax1.tick_params(axis='y', labelcolor=color1)
ax1.set_xticks(range(1, len(nodos)+1))
ax1.set_xlim([0, len(nodos)+1])

ax2 = ax1.twinx()

ax2.set_ylabel('Gflops', color=color2_dark)
ax2.plot(nodos, gflops, color=color1_dark, marker='o', linestyle='--', label='1 nodo malo')
ax2.plot(nodos_extra, gflops_extra, color=color2_dark, marker='o', linestyle='--', label='normal')
ax2.tick_params(axis='y', labelcolor=color2_dark)

plt.title('Gflops vs Tiempo')
plt.legend(loc='upper center')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

nodos = list(range(1, 21))
tareas_por_nodo = 4
tiempo = [1949.51, 872.24, 588.31, 454.89, 375.38, 315.59, 272.35, 247.69, 233.20, 211.49, 205.22, 179.98, 173.37, 165.38, 154.25, 284.55, 147.61, 266.26, 266.62, 241.35]

nodos_extra = list(range(1, 21))
tiempo_extra = [633.87, 334.06, 255.94, 205.84, 184.57, 177.01, 159.65, 144.49, 146.02, 138.39, 134.47, 122.86, 128.06, 129.06, 291.20, 109.06, 271.88, 259.25, 462.81, 243.71]

nodos_optimos = list(range(1, 21))
tiempo_optimos = [354.06, 242.84, 218.53, 205.84, 184.57, 177.01, 159.65, 144.49, 164.13, 147.15, 134.47, 143.36, 128.06, 142.77, 329.28, 138.69, 271.88, 345.92, 462.81, 317.81]

fig, ax1 = plt.subplots()

color1 = '#ff4444'
color1_dark = '#ffbbbb'
color2 = '#4444ff'
color2_dark = "#bbbbff"
color3 = '#44dd44'
color3_dark = "#bbeebb"
ax1.set_xlabel('Nodos (4 hilos)')

# Generate a dense set of x values for smooth plotting
x_dense = np.linspace(1, 20, 300)

ax1.set_ylabel('Tiempo (s)')

# Perform spline interpolation for smooth curves
#spline1 = make_interp_spline(nodos, gflops)
#spline2 = make_interp_spline(nodos_extra, gflops_extra)
#spline3 = make_interp_spline(nodos_optimos, gflops_optimos)

#ax1.plot(x_dense, spline1(x_dense), color=color1_dark, linestyle='--')
#ax1.plot(x_dense, spline2(x_dense), color=color2_dark, linestyle='--')
#ax1.plot(x_dense, spline3(x_dense), color=color3_dark, linestyle='--')

ax1.plot(nodos, tiempo, color=color1_dark, marker='', linestyle='--')
ax1.plot(nodos_extra, tiempo_extra, color=color2_dark, marker='', linestyle='--')
ax1.plot(nodos_optimos, tiempo_optimos, color=color3_dark, marker='', linestyle='--')

ax1.plot(nodos_optimos, tiempo_optimos, color=color3, marker='o', markersize=6, linestyle='', label='P y Q Óptimos')
ax1.plot(nodos_extra, tiempo_extra, color=color2, marker='o', markersize=7, linestyle='', label='Normal (P y Q = hilos y nodos)')
ax1.plot(nodos_optimos, tiempo_optimos, color=color3, marker='o', markersize=4, linestyle='')
ax1.plot(nodos, tiempo, color=color1, marker='o', linestyle='', label='Normal (Conexión deficiente en 1 nodo)')





ax1.set_xticks([1,5,10,15,20])
ax1.set_xlim([0, len(nodos)+1])
ax1.set_ylim(0, 750)

plt.title('Tiempo (s) vs Nodos')
plt.legend(loc='upper center')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import make_interp_spline

nodos = list(range(1, 21))
tareas_por_nodo = 4
gflops = [13.651, 30.512, 45.237, 58.505, 70.897, 84.329, 97.719, 107.45, 114.12, 125.84, 129.68, 147.87, 153.51, 160.92, 172.53, 93.528, 180.30, 99.953, 99.817, 110.27]

nodos_extra = list(range(1, 21))
gflops_extra = [41.986, 79.668, 103.98, 129.29, 144.19, 150.35, 166.70, 184.19, 182.26, 192.31, 197.91, 216.61, 207.82, 206.20, 91.393, 244.03, 97.888, 102.65, 57.504, 109.20]

nodos_optimos = list(range(1, 21))
gflops_optimos = [75.166, 109.59, 121.78, 129.29, 144.19, 150.35, 166.70, 184.19, 162.15, 180.86, 197.91, 185.65, 207.82, 186.41, 80.823, 191.89, 97.888, 76.935, 57.504, 83.739]

fig, ax1 = plt.subplots()

color1 = '#ff4444'
color1_dark = '#ffbbbb'
color2 = '#4444ff'
color2_dark = "#bbbbff"
color3 = '#44dd44'
color3_dark = "#bbeebb"
ax1.set_xlabel('Nodos (4 hilos)')

# Generate a dense set of x values for smooth plotting
x_dense = np.linspace(1, 20, 300)

ax1.set_ylabel('Gflops')

# Perform spline interpolation for smooth curves
#spline1 = make_interp_spline(nodos, gflops)
#spline2 = make_interp_spline(nodos_extra, gflops_extra)
#spline3 = make_interp_spline(nodos_optimos, gflops_optimos)

#ax1.plot(x_dense, spline1(x_dense), color=color1_dark, linestyle='--')
#ax1.plot(x_dense, spline2(x_dense), color=color2_dark, linestyle='--')
#ax1.plot(x_dense, spline3(x_dense), color=color3_dark, linestyle='--')

ax1.plot(nodos, gflops, color=color1_dark, marker='', linestyle='--')
ax1.plot(nodos_extra, gflops_extra, color=color2_dark, marker='', linestyle='--')
ax1.plot(nodos_optimos, gflops_optimos, color=color3_dark, marker='', linestyle='--')

ax1.plot(nodos_optimos, gflops_optimos, color=color3, marker='o', markersize=6, linestyle='', label='P y Q Óptimos')
ax1.plot(nodos_extra, gflops_extra, color=color2, marker='o', markersize=7, linestyle='', label='Normal (P y Q = hilos y nodos)')
ax1.plot(nodos_optimos, gflops_optimos, color=color3, marker='o', markersize=4, linestyle='')
ax1.plot(nodos, gflops, color=color1, marker='o', linestyle='', label='Normal (Conexión deficiente en 1 nodo)')





ax1.set_xticks([1,5,10,15,20])
ax1.set_xlim([0, len(nodos)+1])

plt.title('Gflops vs Nodos')
plt.legend(loc='lower center')
plt.show()
